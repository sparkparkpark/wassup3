# %% [markdown]
# # IMDB - Word2Vec with LSTM
# > ## NLP(Natural Language Processing)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.15.0'

# %% [markdown]
# # I. IMDB Data_Set

# %% [markdown]
# > ## 1) wget From Github
#
# * 'IMDB.zip' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/IMDB.zip
# Out:
# --2024-02-12 13:20:02--  https://raw.githubusercontent.com/rusita-ai/pyData/master/IMDB.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60711700 (58M) [application/zip]
# Saving to: ‘IMDB.zip’
#
# IMDB.zip            100%[===================>]  57.90M   166MB/s    in 0.3s
#
# 2024-02-12 13:20:03 (166 MB/s) - ‘IMDB.zip’ saved [60711700/60711700]

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 59296
# -rw-r--r-- 1 root root 60711700 Feb 12 13:20 IMDB.zip
# drwxr-xr-x 1 root root     4096 Feb  8 14:21 sample_data

# %% [markdown]
# * Unzip 'IMBD.zip'

# %%
# !unzip -q /content/IMDB.zip

# %% [markdown]
# > ## 2) 'texts' and 'labels' Data
#
# * 'texts': 문자열 리스트(영화 감상평)
# * 'lebels': 감상평 리뷰(긍정/부정)

# %%
import os

imdb_dir = 'aclImdb'
train_dir = os.path.join(imdb_dir, 'train')

labels = []
texts = []

for label_type in ['neg', 'pos']:
    dir_name = os.path.join(train_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname[-4:] == '.txt':
            f = open(os.path.join(dir_name, fname), encoding = 'utf8')
            texts.append(f.read())
            f.close()
            if label_type == 'neg':
                labels.append(0)
            else:
                labels.append(1)

# %%
len(labels), len(texts)
# Out:
# (25000, 25000)

# %% [markdown]
# # II. Tensor Transformation

# %% [markdown]
# > ## 1) X_train and X_valid : (25000, 2000)

# %% [markdown]
# * vectorization
#  - (25000, 2000)

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

maxlen = 2000               # 2000개 단어까지 적용
max_words = 10000           # 빈도 높은 10000개 단어 사용

tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('%s개의 고유한 토큰을 찾았습니다.' % len(word_index))

# (25000, 2000)으로 패딩
data = pad_sequences(sequences, maxlen = maxlen)

labels = np.asarray(labels)
print('데이터 텐서의 크기:', data.shape)
print('레이블 텐서의 크기:', labels.shape)


# 샘플 데이터 랜덤화
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]


# 데이터를 훈련 세트와 검증 세트로 분할
training_samples = 15000            # 훈련 샘플은 15000개
validation_samples = 10000          # 검증 샘플은 10000개

X_train = data[:training_samples]
y_train = labels[:training_samples]
X_valid = data[training_samples: training_samples + validation_samples]
y_valid = labels[training_samples: training_samples + validation_samples]
# Out:
# 88582개의 고유한 토큰을 찾았습니다.
# 데이터 텐서의 크기: (25000, 2000)
# 레이블 텐서의 크기: (25000,)

# %% [markdown]
# # III. Word2Vec
#
# https://tfhub.dev/google/Wiki-words-250-with-normalization/2

# %% [markdown]
# > ## 1) Load Pretrained Word2Vec

# %%
import tensorflow_hub as hub

embeddings_index = hub.load('https://tfhub.dev/google/Wiki-words-250/2')

# %% [markdown]
# * Word2Vec 매핑 확인

# %%
embeddings_index(['apple'])
# Out:
# <tf.Tensor: shape=(1, 250), dtype=float32, numpy=
# array([[-7.81319588e-02, -7.97718316e-02,  1.65636316e-02,
#         -1.08001232e-02, -5.10360440e-03,  1.73767412e-03,
#         -5.22104278e-02, -3.89753021e-02,  3.56903672e-02,
#         -3.47909741e-02, -1.01491222e-02,  1.17565657e-03,
#          1.01802059e-01,  1.75360963e-02,  3.36469710e-02,
#          2.79656947e-02,  9.57141817e-02, -7.82085657e-02,
#          5.06314561e-02, -1.66016668e-01,  2.88206208e-02,
#          6.76635057e-02,  9.70917642e-02,  1.79236010e-02,
#         -5.42766303e-02, -1.56506345e-01, -5.30809052e-02,
#         -1.09254161e-03, -1.59554277e-02, -6.70691356e-02,
#          6.15172908e-02,  4.47090678e-02,  4.07696068e-02,
#         -3.83969024e-02,  6.96176291e-02, -5.60147781e-03,
#         -2.26747449e-02, -3.67878452e-02, -5.66431917e-02,
#         -2.18681507e-02, -8.86453837e-02, -2.22746611e-01,
#         -2.07957737e-02,  8.30694276e-04, -3.93166617e-02,
#          5.93367852e-02,  4.33623493e-02,  2.82799695e-02,
#         -3.33397463e-02,  4.76312377e-02, -1.70567650e-02,
#         -2.29284037e-02, -6.83813961e-03,  9.81669277e-02,
#          1.08622149e-01,  2.33869702e-02,  9.60301422e-03,
#         -5.18808290e-02,  9.87230614e-03, -8.69225897e-03,
#         -7.11247921e-02,  7.64381886e-02, -2.43284814e-02,
#         -1.53728379e-02, -1.62205976e-02,  6.06783573e-03,
#         -7.78824538e-02, -4.63543087e-02, -6.10455871e-02,
#          3.76226790e-02, -3.59688103e-02, -2.22809706e-03,
#          7.61934593e-02, -5.42140864e-02,  8.81553534e-03,
#          1.02721518e-02, -2.33051814e-02,  5.69647923e-02,
#         -1.97233241e-02,  5.40813841e-02, -1.06068708e-01,
#         -4.93893884e-02,  7.71986991e-02,  7.54192844e-02,
#         -9.59494933e-02,  1.31888255e-01, -9.32045653e-02,
#          3.91011648e-02,  9.07641053e-02, -1.92628205e-02,
#         -2.80017368e-02,  1.24782704e-01, -4.39715805e-03,
#         -6.76676631e-02,  4.82756756e-02, -8.52152854e-02,
#          2.47792583e-02, -1.15225026e-02, -5.91450334e-02,
#          5.01944311e-02,  6.20031133e-02, -5.91100939e-02,
#         -6.27844781e-02,  1.29692315e-03, -1.05377071e-01,
#         -9.93670970e-02,  3.99318524e-05,  1.49191227e-02,
#          4.78936266e-03, -1.33457212e-02,  3.32747735e-02,
#          1.46604422e-02,  4.45817932e-02, -6.77856291e-03,
#          8.64909738e-02, -5.00659496e-02,  6.05830625e-02,
#         -5.85512519e-02, -7.41328374e-02, -4.07381281e-02,
#         -4.62190509e-02, -2.91668661e-02, -4.27213088e-02,
#         -8.50341916e-02, -7.91059509e-02, -6.71506599e-02,
#          1.28828017e-02, -1.12139061e-02, -2.05859430e-02,
#          2.96257101e-02, -1.02398887e-01, -7.77662396e-02,
#         -1.40929092e-02, -9.11662430e-02, -6.77241236e-02,
#         -7.13218153e-02, -2.31174957e-02, -5.25913984e-02,
#          5.41850226e-03,  4.89527360e-02, -1.23757459e-02,
#          9.59252100e-03, -2.92501189e-02,  6.46212921e-02,
#         -6.40202463e-02,  1.71411615e-02, -1.26278475e-01,
#          6.52319491e-02, -6.71177506e-02, -1.82377342e-02,
#          1.48606636e-02,  5.96186668e-02, -3.32654566e-02,
#          1.99540146e-03, -5.77870682e-02,  5.53884953e-02,
#          1.13689369e-02, -7.79620459e-05, -5.87577112e-02,
#          7.56517053e-02,  4.84508127e-02, -3.61890532e-02,
#         -1.79408665e-03,  2.08812468e-02,  2.92749479e-02,
#         -9.95378569e-02, -2.77001262e-02,  1.80020705e-02,
#          2.97355093e-02, -1.23234659e-01, -5.09306304e-02,
#         -3.30761299e-02, -5.26242852e-02, -3.00878249e-02,
#         -3.25103439e-02,  1.60111822e-02,  3.44622023e-02,
#          5.15305474e-02, -1.93752497e-02,  1.57669075e-02,
#         -3.71751264e-02, -5.06176986e-02,  2.44201999e-02,
#         -1.51907057e-01,  2.39913464e-02, -1.13003314e-01,
#          1.30787894e-01, -4.54162620e-02, -9.83388200e-02,
#         -1.24397818e-02,  5.24396077e-02, -1.16456941e-01,
#          3.62680256e-02,  1.95654272e-03, -1.14642255e-01,
#         -8.16667303e-02,  7.88934752e-02, -1.04228251e-01,
#         -6.75295442e-02, -6.10613637e-02, -8.38295445e-02,
#         -1.31067276e-01,  4.69972305e-02,  3.72825861e-02,
#         -4.98914123e-02,  8.17808285e-02,  3.24426554e-02,
#         -1.22130230e-01,  3.11189927e-02, -7.21874386e-02,
#         -1.13061234e-01,  1.23376660e-02,  7.12911040e-02,
#         -4.75360453e-02,  4.95079681e-02,  1.43659227e-02,
#         -4.67221104e-02, -1.09122954e-01, -1.99307594e-03,
#         -3.16081159e-02,  5.52820191e-02,  6.98578060e-02,
#          3.89518999e-02,  1.15182936e-01,  2.25902516e-02,
#          2.15961877e-02, -1.35523528e-02,  8.84871632e-02,
#          2.74604987e-02,  5.00014126e-02,  3.15750227e-03,
#         -6.46323934e-02, -7.36401677e-02, -9.05453321e-03,
#         -2.28001043e-01,  4.16552834e-02, -7.54309520e-02,
#          2.18629744e-02,  5.21304719e-02,  7.64516816e-02,
#          7.53603727e-02, -1.03571914e-01,  1.18187003e-01,
#          2.14495473e-02,  4.93886471e-02, -2.27750335e-02,
#          3.69624197e-02,  5.50020039e-02, -1.24344015e-02,
#          1.29382275e-02]], dtype=float32)>

# %% [markdown]
# > ## 2) 임베딩 행렬 생성
#
# * (10000, 250)

# %%
# %%time

embedding_dim = 250

embedding_matrix = np.zeros((max_words, embedding_dim))

for word, i in word_index.items():
    embedding_vector = embeddings_index([word])
    if i < max_words:
        if embedding_vector is not None:
            # 임베딩 인덱스에 없는 단어는 모두 0이 됨
            embedding_matrix[i] = embedding_vector
# Out:
# CPU times: user 2min 33s, sys: 11.3 s, total: 2min 44s
# Wall time: 2min 6s

# %% [markdown]
# * 확인

# %%
embedding_matrix.shape
# Out:
# (10000, 250)

# %% [markdown]
# # IV. Keras Embedding Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - max_words: 10000
#  - embedding_dim: 250

# %%
from tensorflow.keras import models, layers

imdb = models.Sequential()

imdb.add(layers.Embedding(input_dim = max_words,
                          output_dim = embedding_dim))
imdb.add(layers.LSTM(32))
imdb.add(layers.Dense(1, activation = 'sigmoid'))

imdb.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 250)         2500000
#
#  lstm (LSTM)                 (None, 32)                36224
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 2536257 (9.68 MB)
# Trainable params: 2536257 (9.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# > ### (1) <font color = 'blue'>'Word2Vec' Embedding Layer Parameter 설정

# %%
imdb.layers[0].set_weights([embedding_matrix])

# %% [markdown]
# > ### (2) <font color = 'red'>'Word2Vec' Embedding Layer Parameter 동결

# %%
imdb.layers[0].trainable = False

# %% [markdown]
# > ### (3) 모델 구조 확인

# %%
imdb.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 250)         2500000
#
#  lstm (LSTM)                 (None, 32)                36224
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 2536257 (9.68 MB)
# Trainable params: 36257 (141.63 KB)
# Non-trainable params: 2500000 (9.54 MB)
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
imdb.compile(loss = 'binary_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 10분

# %%
# %%time

Hist_imdb = imdb.fit(X_train, y_train,
                     epochs = 100,
                     batch_size = 512,
                     validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 10s 211ms/step - loss: 0.6764 - accuracy: 0.5777 - val_loss: 0.6122 - val_accuracy: 0.6732
# Epoch 2/100
# 30/30 [==============================] - 6s 188ms/step - loss: 0.6087 - accuracy: 0.6769 - val_loss: 0.5800 - val_accuracy: 0.7122
# Epoch 3/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.5760 - accuracy: 0.7129 - val_loss: 0.5485 - val_accuracy: 0.7344
# Epoch 4/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.5292 - accuracy: 0.7473 - val_loss: 0.5496 - val_accuracy: 0.7339
# Epoch 5/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.4991 - accuracy: 0.7680 - val_loss: 0.4978 - val_accuracy: 0.7693
# Epoch 6/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.5037 - accuracy: 0.7607 - val_loss: 0.4970 - val_accuracy: 0.7696
# Epoch 7/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.4846 - accuracy: 0.7724 - val_loss: 0.4966 - val_accuracy: 0.7672
# Epoch 8/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.4837 - accuracy: 0.7775 - val_loss: 0.4724 - val_accuracy: 0.7792
# Epoch 9/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4607 - accuracy: 0.7902 - val_loss: 0.4812 - val_accuracy: 0.7760
# Epoch 10/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.4566 - accuracy: 0.7929 - val_loss: 0.4487 - val_accuracy: 0.7971
# Epoch 11/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.4419 - accuracy: 0.8007 - val_loss: 0.4604 - val_accuracy: 0.7835
# Epoch 12/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.4557 - accuracy: 0.7921 - val_loss: 0.4864 - val_accuracy: 0.7768
# Epoch 13/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4418 - accuracy: 0.7967 - val_loss: 0.4508 - val_accuracy: 0.7936
# Epoch 14/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4573 - accuracy: 0.7937 - val_loss: 0.4884 - val_accuracy: 0.7660
# Epoch 15/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.4607 - accuracy: 0.7885 - val_loss: 0.4433 - val_accuracy: 0.7940
# Epoch 16/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.4468 - accuracy: 0.7961 - val_loss: 0.4466 - val_accuracy: 0.7916
# Epoch 17/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4305 - accuracy: 0.8063 - val_loss: 0.4355 - val_accuracy: 0.8026
# Epoch 18/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.4413 - accuracy: 0.7994 - val_loss: 0.4600 - val_accuracy: 0.7826
# Epoch 19/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4410 - accuracy: 0.8041 - val_loss: 0.4279 - val_accuracy: 0.8089
# Epoch 20/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.4199 - accuracy: 0.8127 - val_loss: 0.5048 - val_accuracy: 0.7576
# Epoch 21/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4199 - accuracy: 0.8103 - val_loss: 0.4165 - val_accuracy: 0.8101
# Epoch 22/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4074 - accuracy: 0.8200 - val_loss: 0.4063 - val_accuracy: 0.8184
# Epoch 23/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.4087 - accuracy: 0.8187 - val_loss: 0.4213 - val_accuracy: 0.8037
# Epoch 24/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4052 - accuracy: 0.8220 - val_loss: 0.4402 - val_accuracy: 0.7895
# Epoch 25/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4027 - accuracy: 0.8243 - val_loss: 0.4003 - val_accuracy: 0.8184
# Epoch 26/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.4097 - accuracy: 0.8190 - val_loss: 0.4030 - val_accuracy: 0.8186
# Epoch 27/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.4046 - accuracy: 0.8216 - val_loss: 0.4022 - val_accuracy: 0.8193
# Epoch 28/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4000 - accuracy: 0.8227 - val_loss: 0.4366 - val_accuracy: 0.7933
# Epoch 29/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3979 - accuracy: 0.8251 - val_loss: 0.4211 - val_accuracy: 0.8139
# Epoch 30/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4133 - accuracy: 0.8154 - val_loss: 0.4012 - val_accuracy: 0.8228
# Epoch 31/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3933 - accuracy: 0.8275 - val_loss: 0.4138 - val_accuracy: 0.8103
# Epoch 32/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4078 - accuracy: 0.8203 - val_loss: 0.4807 - val_accuracy: 0.7601
# Epoch 33/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4091 - accuracy: 0.8161 - val_loss: 0.3916 - val_accuracy: 0.8259
# Epoch 34/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3789 - accuracy: 0.8366 - val_loss: 0.3870 - val_accuracy: 0.8273
# Epoch 35/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3798 - accuracy: 0.8340 - val_loss: 0.4038 - val_accuracy: 0.8158
# Epoch 36/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3838 - accuracy: 0.8340 - val_loss: 0.3915 - val_accuracy: 0.8222
# Epoch 37/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3721 - accuracy: 0.8399 - val_loss: 0.3873 - val_accuracy: 0.8278
# Epoch 38/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3782 - accuracy: 0.8360 - val_loss: 0.3799 - val_accuracy: 0.8319
# Epoch 39/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3797 - accuracy: 0.8377 - val_loss: 0.4139 - val_accuracy: 0.8106
# Epoch 40/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.4149 - accuracy: 0.8175 - val_loss: 0.3940 - val_accuracy: 0.8208
# Epoch 41/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3813 - accuracy: 0.8327 - val_loss: 0.3988 - val_accuracy: 0.8185
# Epoch 42/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3701 - accuracy: 0.8413 - val_loss: 0.4107 - val_accuracy: 0.8108
# Epoch 43/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3813 - accuracy: 0.8339 - val_loss: 0.3996 - val_accuracy: 0.8207
# Epoch 44/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3677 - accuracy: 0.8414 - val_loss: 0.3973 - val_accuracy: 0.8207
# Epoch 45/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3660 - accuracy: 0.8453 - val_loss: 0.3766 - val_accuracy: 0.8333
# Epoch 46/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3671 - accuracy: 0.8444 - val_loss: 0.3792 - val_accuracy: 0.8331
# Epoch 47/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3725 - accuracy: 0.8415 - val_loss: 0.4169 - val_accuracy: 0.8098
# Epoch 48/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3710 - accuracy: 0.8402 - val_loss: 0.3825 - val_accuracy: 0.8323
# Epoch 49/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3793 - accuracy: 0.8347 - val_loss: 0.3864 - val_accuracy: 0.8299
# Epoch 50/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3636 - accuracy: 0.8459 - val_loss: 0.3733 - val_accuracy: 0.8376
# Epoch 51/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3615 - accuracy: 0.8460 - val_loss: 0.4126 - val_accuracy: 0.8219
# Epoch 52/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3652 - accuracy: 0.8438 - val_loss: 0.3887 - val_accuracy: 0.8271
# Epoch 53/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3534 - accuracy: 0.8489 - val_loss: 0.3918 - val_accuracy: 0.8312
# Epoch 54/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3629 - accuracy: 0.8469 - val_loss: 0.3856 - val_accuracy: 0.8268
# Epoch 55/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3618 - accuracy: 0.8440 - val_loss: 0.3957 - val_accuracy: 0.8214
# Epoch 56/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3577 - accuracy: 0.8451 - val_loss: 0.3661 - val_accuracy: 0.8403
# Epoch 57/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3543 - accuracy: 0.8483 - val_loss: 0.3633 - val_accuracy: 0.8393
# Epoch 58/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3543 - accuracy: 0.8483 - val_loss: 0.4102 - val_accuracy: 0.8053
# Epoch 59/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3587 - accuracy: 0.8443 - val_loss: 0.3828 - val_accuracy: 0.8294
# Epoch 60/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3600 - accuracy: 0.8451 - val_loss: 0.3778 - val_accuracy: 0.8305
# Epoch 61/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3626 - accuracy: 0.8435 - val_loss: 0.3715 - val_accuracy: 0.8381
# Epoch 62/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3493 - accuracy: 0.8495 - val_loss: 0.3628 - val_accuracy: 0.8414
# Epoch 63/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.3529 - accuracy: 0.8500 - val_loss: 0.3595 - val_accuracy: 0.8419
# Epoch 64/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3525 - accuracy: 0.8510 - val_loss: 0.3620 - val_accuracy: 0.8402
# Epoch 65/100
# 30/30 [==============================] - 5s 184ms/step - loss: 0.3561 - accuracy: 0.8470 - val_loss: 0.4099 - val_accuracy: 0.8132
# Epoch 66/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3527 - accuracy: 0.8473 - val_loss: 0.4925 - val_accuracy: 0.7908
# Epoch 67/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3690 - accuracy: 0.8411 - val_loss: 0.4109 - val_accuracy: 0.8126
# Epoch 68/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3623 - accuracy: 0.8468 - val_loss: 0.3742 - val_accuracy: 0.8382
# Epoch 69/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3699 - accuracy: 0.8379 - val_loss: 0.3687 - val_accuracy: 0.8360
# Epoch 70/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3484 - accuracy: 0.8510 - val_loss: 0.3552 - val_accuracy: 0.8432
# Epoch 71/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3446 - accuracy: 0.8547 - val_loss: 0.3592 - val_accuracy: 0.8429
# Epoch 72/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3498 - accuracy: 0.8527 - val_loss: 0.3651 - val_accuracy: 0.8437
# Epoch 73/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3363 - accuracy: 0.8585 - val_loss: 0.3600 - val_accuracy: 0.8408
# Epoch 74/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3356 - accuracy: 0.8591 - val_loss: 0.3702 - val_accuracy: 0.8390
# Epoch 75/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3337 - accuracy: 0.8598 - val_loss: 0.3538 - val_accuracy: 0.8469
# Epoch 76/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3310 - accuracy: 0.8610 - val_loss: 0.3550 - val_accuracy: 0.8469
# Epoch 77/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3422 - accuracy: 0.8531 - val_loss: 0.3539 - val_accuracy: 0.8460
# Epoch 78/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3308 - accuracy: 0.8601 - val_loss: 0.3641 - val_accuracy: 0.8385
# Epoch 79/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3452 - accuracy: 0.8521 - val_loss: 0.3717 - val_accuracy: 0.8441
# Epoch 80/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3412 - accuracy: 0.8538 - val_loss: 0.4093 - val_accuracy: 0.8324
# Epoch 81/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3537 - accuracy: 0.8477 - val_loss: 0.3487 - val_accuracy: 0.8476
# Epoch 82/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.3292 - accuracy: 0.8627 - val_loss: 0.3716 - val_accuracy: 0.8348
# Epoch 83/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3308 - accuracy: 0.8592 - val_loss: 0.3455 - val_accuracy: 0.8502
# Epoch 84/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3283 - accuracy: 0.8637 - val_loss: 0.3506 - val_accuracy: 0.8506
# Epoch 85/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3346 - accuracy: 0.8581 - val_loss: 0.4042 - val_accuracy: 0.8302
# Epoch 86/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3418 - accuracy: 0.8569 - val_loss: 0.3811 - val_accuracy: 0.8382
# Epoch 87/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3229 - accuracy: 0.8657 - val_loss: 0.3763 - val_accuracy: 0.8438
# Epoch 88/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3332 - accuracy: 0.8581 - val_loss: 0.3852 - val_accuracy: 0.8344
# Epoch 89/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3299 - accuracy: 0.8610 - val_loss: 0.3579 - val_accuracy: 0.8417
# Epoch 90/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3214 - accuracy: 0.8642 - val_loss: 0.3436 - val_accuracy: 0.8508
# Epoch 91/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3154 - accuracy: 0.8669 - val_loss: 0.3411 - val_accuracy: 0.8523
# Epoch 92/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3203 - accuracy: 0.8663 - val_loss: 0.3553 - val_accuracy: 0.8407
# Epoch 93/100
# 30/30 [==============================] - 5s 182ms/step - loss: 0.3191 - accuracy: 0.8634 - val_loss: 0.3813 - val_accuracy: 0.8342
# Epoch 94/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3297 - accuracy: 0.8603 - val_loss: 0.3477 - val_accuracy: 0.8498
# Epoch 95/100
# 30/30 [==============================] - 5s 184ms/step - loss: 0.3165 - accuracy: 0.8649 - val_loss: 0.3389 - val_accuracy: 0.8543
# Epoch 96/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3157 - accuracy: 0.8671 - val_loss: 0.3671 - val_accuracy: 0.8398
# Epoch 97/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3189 - accuracy: 0.8667 - val_loss: 0.3916 - val_accuracy: 0.8246
# Epoch 98/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.3225 - accuracy: 0.8651 - val_loss: 0.3374 - val_accuracy: 0.8563
# Epoch 99/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3127 - accuracy: 0.8719 - val_loss: 0.3538 - val_accuracy: 0.8461
# Epoch 100/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.3173 - accuracy: 0.8671 - val_loss: 0.3827 - val_accuracy: 0.8377
# CPU times: user 7min 17s, sys: 1min 18s, total: 8min 36s
# Wall time: 9min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss & Accuracy Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_imdb.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_imdb.history['loss'], 'b-')
plt.plot(epochs, Hist_imdb.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_imdb.history['accuracy'], 'b-')
plt.plot(epochs, Hist_imdb.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = imdb.evaluate(X_valid, y_valid)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 8s 27ms/step - loss: 0.3827 - accuracy: 0.8377
# Loss = 0.38272
# Accuracy = 0.83770

# %% [markdown]
# # The End
