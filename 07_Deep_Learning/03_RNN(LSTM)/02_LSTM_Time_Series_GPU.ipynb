# %% [markdown]
# # LSTM - Time Serise Dataset
#
# * 서울시 기후 데이터 : 2011년 01월 01일 ~ 2019년 12월 31일
# * https://data.kma.go.kr/cmmn/main.do
# * 기후통계분석 -> 기온분석 -> 기간(20110101~20191231) -> 검색 -> CSV 다운로드
# * Seoul_Temp.csv

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Packages
#
# * Packages

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # 1. Colab File Upload

# %% [markdown]
# > ## 1) 'Seoul_Temp.csv' 파일을 Colab에 업로드 후 진행

# %%
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/Seoul_Temp.csv'
temp = pd.read_csv(url)

temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3287 non-null   object
#  1   avg     3287 non-null   float64
#  2   min     3287 non-null   float64
#  3   max     3287 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 102.8+ KB

# %%
temp.head()
# Out:
#          date  avg   min  max
# 0  2011-01-01 -6.8 -10.4 -2.9
# 1  2011-01-02 -5.4  -8.5 -1.2
# 2  2011-01-03 -4.5  -8.5 -0.3
# 3  2011-01-04 -3.9  -7.4 -1.7
# 4  2011-01-05 -4.0  -7.7 -1.8

# %%
temp.tail()
# Out:
#             date  avg   min  max
# 3282  2019-12-27 -1.7  -4.6  2.6
# 3283  2019-12-28  1.1  -3.6  6.1
# 3284  2019-12-29  3.8   1.1  6.2
# 3285  2019-12-30  2.7  -5.7  6.8
# 3286  2019-12-31 -7.9 -10.9 -4.5

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# > ## 1) 일일 평균온도('avg') 변화 시각화
#
# * 일일 평균온도 변화에 일정한 패턴 확인

# %%
temp_data = temp[['avg']]

plt.figure(figsize = (12, 5))
plt.plot(temp_data)
plt.show()

# %% [markdown]
# > ## 2) Normalization
#
# * tanh Activation 적용을 위해 -1 ~ 1 범위로 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

temp_data = scaler.fit_transform(temp_data)

# %% [markdown]
# > ## 3) Train vs. Test Split
# - 시간의 순서가 중요하므로 random split하면 안됨(싸이킷런 함수)
# * Train_Dataset : 2011년 01월 01일 ~ 2017년 12월 31일
# * Test_Dataset : 2018년 01월 01일 ~ 2019년 12월 31일

# %%
train = temp_data[0:2557]
test  = temp_data[2557:]

# %%
train
# Out:
# array([[-0.67010309],
#        [-0.61237113],
#        [-0.57525773],
#        ...,
#        [-0.30309278],
#        [-0.33195876],
#        [-0.40206186]])

# %% [markdown]
# # 3. 시계열 데이터 처리 함수

# %% [markdown]
# > ## 1) 시계열 학습용 데이터 생성 함수 정의
#
# * X : 학습 평균온도 데이터
# * y : 정답 평균온도 데이터
# * 일정 기간의 X로 y를 예측하도록 학습
# * 예를 들어, look_back이 2일 때, time_data가 [1, 2, 3, 4, 5]라면, data_X는 [[1, 2], [2, 3], [3, 4]]가 되고, data_y는 [3, 4, 5]가 됩니다.

# %%
def create_dataset(time_data, look_back = 1):
    data_X, data_y = [], []

    for i in range(len(time_data) - look_back):
        data_X.append(time_data[i:(i + look_back), 0])
        data_y.append(time_data[i + look_back, 0])

    return np.array(data_X), np.array(data_y)

# %% [markdown]
# > ## 2) loop_back 기간 설정 후 학습데이터 생성
#
# * 180일 기간 평균온도로 다음날 평균온도 예측 데이터 생성

# %%
look_back = 180

train_X, train_y = create_dataset(train, look_back)
test_X,  test_y  = create_dataset(test, look_back)

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180), (2377,), (550, 180), (550,))

# %%
train_X
# Out:
# array([[-0.67010309, -0.61237113, -0.57525773, ...,  0.40206186,
#          0.60412371,  0.47628866],
#        [-0.61237113, -0.57525773, -0.55051546, ...,  0.60412371,
#          0.47628866,  0.59175258],
#        [-0.57525773, -0.55051546, -0.55463918, ...,  0.47628866,
#          0.59175258,  0.64536082],
#        ...,
#        [ 0.61237113,  0.62886598,  0.71134021, ..., -0.54639175,
#         -0.6742268 , -0.47628866],
#        [ 0.62886598,  0.71134021,  0.74020619, ..., -0.6742268 ,
#         -0.47628866, -0.30309278],
#        [ 0.71134021,  0.74020619,  0.74845361, ..., -0.47628866,
#         -0.30309278, -0.33195876]])

# %%
train_y
# Out:
# array([ 0.59175258,  0.64536082,  0.62886598, ..., -0.30309278,
#        -0.33195876, -0.40206186])

# %% [markdown]
# > ## 3) Tensor Reshape

# %%
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180, 1), (2377,), (550, 180, 1), (550,))

# %% [markdown]
# # 4. LSTM

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential(name = 'LSTM')
model.add(LSTM(128,
               input_shape = (None, 1)))

model.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# * Model Summary

# %%
model.summary()
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 66689 (260.50 KB)
# Trainable params: 66689 (260.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
model.compile(loss = 'mse',
              optimizer = 'adam',
              metrics = ['mae'])

# %% [markdown]
# > ## 3) Model Fit
#
# * 약 6분

# %%
# %%time

hist = model.fit(train_X, train_y,
                 epochs = 100,
                 batch_size = 16,
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/100
# 149/149 [==============================] - 11s 27ms/step - loss: 0.0210 - mae: 0.1089 - val_loss: 0.0197 - val_mae: 0.1118
# Epoch 2/100
# 149/149 [==============================] - 4s 24ms/step - loss: 0.0144 - mae: 0.0917 - val_loss: 0.0120 - val_mae: 0.0847
# Epoch 3/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0123 - mae: 0.0841 - val_loss: 0.0105 - val_mae: 0.0772
# Epoch 4/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0111 - mae: 0.0805 - val_loss: 0.0102 - val_mae: 0.0772
# Epoch 5/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0103 - mae: 0.0772 - val_loss: 0.0092 - val_mae: 0.0746
# Epoch 6/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0098 - mae: 0.0752 - val_loss: 0.0088 - val_mae: 0.0730
# Epoch 7/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0094 - mae: 0.0735 - val_loss: 0.0082 - val_mae: 0.0692
# Epoch 8/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0091 - mae: 0.0721 - val_loss: 0.0082 - val_mae: 0.0691
# Epoch 9/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0089 - mae: 0.0714 - val_loss: 0.0081 - val_mae: 0.0680
# Epoch 10/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0088 - mae: 0.0710 - val_loss: 0.0081 - val_mae: 0.0691
# Epoch 11/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0087 - mae: 0.0703 - val_loss: 0.0079 - val_mae: 0.0682
# Epoch 12/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0079 - val_mae: 0.0672
# Epoch 13/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0083 - val_mae: 0.0701
# Epoch 14/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0077 - val_mae: 0.0665
# Epoch 15/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0084 - mae: 0.0693 - val_loss: 0.0078 - val_mae: 0.0670
# Epoch 16/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0084 - mae: 0.0688 - val_loss: 0.0085 - val_mae: 0.0719
# Epoch 17/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0085 - mae: 0.0692 - val_loss: 0.0081 - val_mae: 0.0696
# Epoch 18/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0084 - mae: 0.0690 - val_loss: 0.0078 - val_mae: 0.0673
# Epoch 19/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0083 - mae: 0.0685 - val_loss: 0.0084 - val_mae: 0.0715
# Epoch 20/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0690 - val_loss: 0.0078 - val_mae: 0.0675
# Epoch 21/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - mae: 0.0688 - val_loss: 0.0083 - val_mae: 0.0709
# Epoch 22/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0084 - mae: 0.0690 - val_loss: 0.0081 - val_mae: 0.0699
# Epoch 23/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0689 - val_loss: 0.0077 - val_mae: 0.0668
# Epoch 24/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0084 - mae: 0.0686 - val_loss: 0.0078 - val_mae: 0.0668
# Epoch 25/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0084 - mae: 0.0686 - val_loss: 0.0078 - val_mae: 0.0674
# Epoch 26/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0083 - mae: 0.0687 - val_loss: 0.0076 - val_mae: 0.0664
# Epoch 27/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0084 - mae: 0.0686 - val_loss: 0.0076 - val_mae: 0.0661
# Epoch 28/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - mae: 0.0687 - val_loss: 0.0081 - val_mae: 0.0674
# Epoch 29/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0688 - val_loss: 0.0076 - val_mae: 0.0661
# Epoch 30/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0083 - mae: 0.0684 - val_loss: 0.0076 - val_mae: 0.0655
# Epoch 31/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0083 - mae: 0.0680 - val_loss: 0.0081 - val_mae: 0.0688
# Epoch 32/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0083 - mae: 0.0684 - val_loss: 0.0076 - val_mae: 0.0656
# Epoch 33/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0083 - mae: 0.0686 - val_loss: 0.0076 - val_mae: 0.0656
# Epoch 34/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0082 - mae: 0.0681 - val_loss: 0.0075 - val_mae: 0.0659
# Epoch 35/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0082 - mae: 0.0678 - val_loss: 0.0078 - val_mae: 0.0678
# Epoch 36/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0083 - mae: 0.0681 - val_loss: 0.0077 - val_mae: 0.0660
# Epoch 37/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0083 - mae: 0.0680 - val_loss: 0.0075 - val_mae: 0.0656
# Epoch 38/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - mae: 0.0677 - val_loss: 0.0078 - val_mae: 0.0679
# Epoch 39/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - mae: 0.0683 - val_loss: 0.0076 - val_mae: 0.0664
# Epoch 40/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0082 - mae: 0.0676 - val_loss: 0.0078 - val_mae: 0.0664
# Epoch 41/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0082 - mae: 0.0675 - val_loss: 0.0079 - val_mae: 0.0687
# Epoch 42/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - mae: 0.0679 - val_loss: 0.0076 - val_mae: 0.0670
# Epoch 43/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - mae: 0.0677 - val_loss: 0.0075 - val_mae: 0.0663
# Epoch 44/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - mae: 0.0678 - val_loss: 0.0079 - val_mae: 0.0692
# Epoch 45/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - mae: 0.0675 - val_loss: 0.0077 - val_mae: 0.0663
# Epoch 46/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - mae: 0.0677 - val_loss: 0.0074 - val_mae: 0.0655
# Epoch 47/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0082 - mae: 0.0674 - val_loss: 0.0076 - val_mae: 0.0673
# Epoch 48/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0082 - mae: 0.0677 - val_loss: 0.0074 - val_mae: 0.0649
# Epoch 49/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0077 - val_mae: 0.0677
# Epoch 50/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0079 - val_mae: 0.0676
# Epoch 51/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0079 - val_mae: 0.0672
# Epoch 52/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - mae: 0.0671 - val_loss: 0.0079 - val_mae: 0.0697
# Epoch 53/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0675 - val_loss: 0.0075 - val_mae: 0.0660
# Epoch 54/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0672 - val_loss: 0.0076 - val_mae: 0.0654
# Epoch 55/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0081 - val_mae: 0.0706
# Epoch 56/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0073 - val_mae: 0.0649
# Epoch 57/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0081 - val_mae: 0.0689
# Epoch 58/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0090 - val_mae: 0.0728
# Epoch 59/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0075 - val_mae: 0.0652
# Epoch 60/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0677 - val_loss: 0.0073 - val_mae: 0.0644
# Epoch 61/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0075 - val_mae: 0.0661
# Epoch 62/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0079 - val_mae: 0.0683
# Epoch 63/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0079 - val_mae: 0.0675
# Epoch 64/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0080 - val_mae: 0.0698
# Epoch 65/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0074 - val_mae: 0.0659
# Epoch 66/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 67/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - mae: 0.0672 - val_loss: 0.0073 - val_mae: 0.0653
# Epoch 68/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - mae: 0.0670 - val_loss: 0.0075 - val_mae: 0.0663
# Epoch 69/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0074 - val_mae: 0.0654
# Epoch 70/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0079 - val_mae: 0.0680
# Epoch 71/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0076 - val_mae: 0.0670
# Epoch 72/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0076 - val_mae: 0.0661
# Epoch 73/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0075 - val_mae: 0.0667
# Epoch 74/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0077 - val_mae: 0.0680
# Epoch 75/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0676 - val_loss: 0.0074 - val_mae: 0.0654
# Epoch 76/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0076 - val_mae: 0.0676
# Epoch 77/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0077 - val_mae: 0.0675
# Epoch 78/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0073 - val_mae: 0.0646
# Epoch 79/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0073 - val_mae: 0.0652
# Epoch 80/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0076 - val_mae: 0.0668
# Epoch 81/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 82/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0666 - val_loss: 0.0074 - val_mae: 0.0664
# Epoch 83/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0076 - val_mae: 0.0654
# Epoch 84/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0076 - val_mae: 0.0673
# Epoch 85/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0080 - mae: 0.0675 - val_loss: 0.0074 - val_mae: 0.0654
# Epoch 86/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0659
# Epoch 87/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0074 - val_mae: 0.0651
# Epoch 88/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0073 - val_mae: 0.0645
# Epoch 89/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0073 - val_mae: 0.0656
# Epoch 90/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - mae: 0.0671 - val_loss: 0.0075 - val_mae: 0.0660
# Epoch 91/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0075 - val_mae: 0.0659
# Epoch 92/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0076 - val_mae: 0.0679
# Epoch 93/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0080 - val_mae: 0.0692
# Epoch 94/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0076 - val_mae: 0.0668
# Epoch 95/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0077 - val_mae: 0.0675
# Epoch 96/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0076 - val_mae: 0.0670
# Epoch 97/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0075 - val_mae: 0.0664
# Epoch 98/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0074 - val_mae: 0.0658
# Epoch 99/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - mae: 0.0662 - val_loss: 0.0086 - val_mae: 0.0716
# Epoch 100/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0074 - val_mae: 0.0654
# CPU times: user 2min 58s, sys: 8.6 s, total: 3min 6s
# Wall time: 3min 25s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.007765896152704954, 0.06592345982789993]
# Test Score:  [0.007371590472757816, 0.06539533287286758]

# %% [markdown]
# ## 6) Model Predict

# %%
look_ahead = 550

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size = 1, verbose = 0)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])

plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')
plt.legend()
plt.show()

# %% [markdown]
# # 5. Stacked LSTM Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model2 = Sequential(name = 'Stackd_LSTM')
model2.add(LSTM(64,
               input_shape = (None, 1),
               return_sequences = True))
model2.add(LSTM(64,
               input_shape = (None, 1),
               return_sequences = False))
model2.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# * Model Summary

# %%
model2.summary()
# Out:
# Model: "Stackd_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, None, 64)          16896
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 49985 (195.25 KB)
# Trainable params: 49985 (195.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
model2.compile(loss = 'mse',
              optimizer = 'adam',
              metrics = ['mae'])

# %% [markdown]
# > ## 3) Model Fit
#
# * 약 10분

# %%
# %%time

hist2 = model2.fit(train_X, train_y,
                 epochs = 100,
                 batch_size = 16,
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/100
# 149/149 [==============================] - 6s 21ms/step - loss: 0.0262 - mae: 0.1191 - val_loss: 0.0177 - val_mae: 0.1045
# Epoch 2/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0180 - mae: 0.1029 - val_loss: 0.0155 - val_mae: 0.0986
# Epoch 3/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0165 - mae: 0.0996 - val_loss: 0.0139 - val_mae: 0.0923
# Epoch 4/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0153 - mae: 0.0950 - val_loss: 0.0151 - val_mae: 0.0977
# Epoch 5/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0141 - mae: 0.0910 - val_loss: 0.0142 - val_mae: 0.0925
# Epoch 6/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0130 - mae: 0.0880 - val_loss: 0.0123 - val_mae: 0.0852
# Epoch 7/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0122 - mae: 0.0843 - val_loss: 0.0102 - val_mae: 0.0783
# Epoch 8/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0110 - mae: 0.0802 - val_loss: 0.0107 - val_mae: 0.0829
# Epoch 9/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0103 - mae: 0.0775 - val_loss: 0.0089 - val_mae: 0.0734
# Epoch 10/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0097 - mae: 0.0749 - val_loss: 0.0093 - val_mae: 0.0765
# Epoch 11/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0091 - mae: 0.0723 - val_loss: 0.0090 - val_mae: 0.0731
# Epoch 12/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0088 - mae: 0.0714 - val_loss: 0.0083 - val_mae: 0.0696
# Epoch 13/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0086 - mae: 0.0702 - val_loss: 0.0079 - val_mae: 0.0689
# Epoch 14/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0087 - mae: 0.0701 - val_loss: 0.0079 - val_mae: 0.0682
# Epoch 15/100
# 149/149 [==============================] - 4s 24ms/step - loss: 0.0085 - mae: 0.0697 - val_loss: 0.0083 - val_mae: 0.0699
# Epoch 16/100
# 149/149 [==============================] - 5s 33ms/step - loss: 0.0085 - mae: 0.0693 - val_loss: 0.0082 - val_mae: 0.0700
# Epoch 17/100
# 149/149 [==============================] - 5s 37ms/step - loss: 0.0084 - mae: 0.0690 - val_loss: 0.0082 - val_mae: 0.0713
# Epoch 18/100
# 149/149 [==============================] - 4s 26ms/step - loss: 0.0085 - mae: 0.0688 - val_loss: 0.0078 - val_mae: 0.0669
# Epoch 19/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0084 - mae: 0.0689 - val_loss: 0.0078 - val_mae: 0.0672
# Epoch 20/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0083 - mae: 0.0685 - val_loss: 0.0095 - val_mae: 0.0778
# Epoch 21/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0082 - mae: 0.0683 - val_loss: 0.0097 - val_mae: 0.0791
# Epoch 22/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0083 - mae: 0.0682 - val_loss: 0.0080 - val_mae: 0.0699
# Epoch 23/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0084 - mae: 0.0686 - val_loss: 0.0081 - val_mae: 0.0700
# Epoch 24/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0083 - mae: 0.0680 - val_loss: 0.0080 - val_mae: 0.0685
# Epoch 25/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0082 - mae: 0.0680 - val_loss: 0.0083 - val_mae: 0.0718
# Epoch 26/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0083 - mae: 0.0684 - val_loss: 0.0080 - val_mae: 0.0687
# Epoch 27/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0083 - mae: 0.0683 - val_loss: 0.0076 - val_mae: 0.0670
# Epoch 28/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0082 - mae: 0.0682 - val_loss: 0.0078 - val_mae: 0.0677
# Epoch 29/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0082 - mae: 0.0682 - val_loss: 0.0075 - val_mae: 0.0651
# Epoch 30/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0082 - mae: 0.0674 - val_loss: 0.0078 - val_mae: 0.0683
# Epoch 31/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0081 - val_mae: 0.0691
# Epoch 32/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0081 - mae: 0.0677 - val_loss: 0.0077 - val_mae: 0.0670
# Epoch 33/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0082 - mae: 0.0675 - val_loss: 0.0076 - val_mae: 0.0673
# Epoch 34/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0082 - mae: 0.0674 - val_loss: 0.0076 - val_mae: 0.0656
# Epoch 35/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0079 - val_mae: 0.0685
# Epoch 36/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0082 - mae: 0.0676 - val_loss: 0.0073 - val_mae: 0.0654
# Epoch 37/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0672 - val_loss: 0.0075 - val_mae: 0.0652
# Epoch 38/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0082 - mae: 0.0680 - val_loss: 0.0073 - val_mae: 0.0653
# Epoch 39/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0077 - val_mae: 0.0672
# Epoch 40/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0082 - mae: 0.0675 - val_loss: 0.0076 - val_mae: 0.0671
# Epoch 41/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0082 - mae: 0.0679 - val_loss: 0.0074 - val_mae: 0.0645
# Epoch 42/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0080 - val_mae: 0.0681
# Epoch 43/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0081 - mae: 0.0677 - val_loss: 0.0076 - val_mae: 0.0668
# Epoch 44/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0074 - val_mae: 0.0658
# Epoch 45/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0073 - val_mae: 0.0645
# Epoch 46/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0075 - val_mae: 0.0650
# Epoch 47/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0080 - val_mae: 0.0684
# Epoch 48/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0077 - val_mae: 0.0670
# Epoch 49/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0677 - val_loss: 0.0075 - val_mae: 0.0653
# Epoch 50/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0077 - val_mae: 0.0674
# Epoch 51/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0081 - mae: 0.0672 - val_loss: 0.0075 - val_mae: 0.0654
# Epoch 52/100
# 149/149 [==============================] - 4s 25ms/step - loss: 0.0082 - mae: 0.0676 - val_loss: 0.0073 - val_mae: 0.0645
# Epoch 53/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0079 - val_mae: 0.0661
# Epoch 54/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0075 - val_mae: 0.0664
# Epoch 55/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0077 - val_mae: 0.0682
# Epoch 56/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0075 - val_mae: 0.0661
# Epoch 57/100
# 149/149 [==============================] - 3s 23ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0078 - val_mae: 0.0681
# Epoch 58/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0079 - val_mae: 0.0683
# Epoch 59/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0073 - val_mae: 0.0642
# Epoch 60/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0670 - val_loss: 0.0076 - val_mae: 0.0677
# Epoch 61/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0081 - mae: 0.0671 - val_loss: 0.0078 - val_mae: 0.0669
# Epoch 62/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0081 - val_mae: 0.0681
# Epoch 63/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0076 - val_mae: 0.0666
# Epoch 64/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0081 - mae: 0.0676 - val_loss: 0.0077 - val_mae: 0.0659
# Epoch 65/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0673 - val_loss: 0.0077 - val_mae: 0.0682
# Epoch 66/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0073 - val_mae: 0.0641
# Epoch 67/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0674 - val_loss: 0.0072 - val_mae: 0.0640
# Epoch 68/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0669 - val_loss: 0.0076 - val_mae: 0.0679
# Epoch 69/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0674 - val_loss: 0.0085 - val_mae: 0.0687
# Epoch 70/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0077 - val_mae: 0.0673
# Epoch 71/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0650
# Epoch 72/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0080 - val_mae: 0.0665
# Epoch 73/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0668
# Epoch 74/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0076 - val_mae: 0.0659
# Epoch 75/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0072 - val_mae: 0.0645
# Epoch 76/100
# 149/149 [==============================] - 4s 27ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0074 - val_mae: 0.0645
# Epoch 77/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0072 - val_mae: 0.0642
# Epoch 78/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0073 - val_mae: 0.0654
# Epoch 79/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 80/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0672 - val_loss: 0.0078 - val_mae: 0.0665
# Epoch 81/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0074 - val_mae: 0.0642
# Epoch 82/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0075 - val_mae: 0.0668
# Epoch 83/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0087 - val_mae: 0.0726
# Epoch 84/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0664
# Epoch 85/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0076 - val_mae: 0.0675
# Epoch 86/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0079 - val_mae: 0.0697
# Epoch 87/100
# 149/149 [==============================] - 4s 25ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0073 - val_mae: 0.0644
# Epoch 88/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0073 - val_mae: 0.0644
# Epoch 89/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0073 - val_mae: 0.0642
# Epoch 90/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0074 - val_mae: 0.0647
# Epoch 91/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0078 - val_mae: 0.0664
# Epoch 92/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0074 - val_mae: 0.0645
# Epoch 93/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0074 - val_mae: 0.0648
# Epoch 94/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0076 - val_mae: 0.0659
# Epoch 95/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0080 - mae: 0.0668 - val_loss: 0.0076 - val_mae: 0.0675
# Epoch 96/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0073 - val_mae: 0.0647
# Epoch 97/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0075 - val_mae: 0.0668
# Epoch 98/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0073 - val_mae: 0.0641
# Epoch 99/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0072 - val_mae: 0.0636
# Epoch 100/100
# 149/149 [==============================] - 4s 25ms/step - loss: 0.0078 - mae: 0.0664 - val_loss: 0.0075 - val_mae: 0.0649
# CPU times: user 4min 31s, sys: 10.6 s, total: 4min 41s
# Wall time: 5min 24s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist2.history['loss'])
plt.plot(hist2.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model2.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model2.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.007967359386384487, 0.06521724909543991]
# Test Score:  [0.007540363818407059, 0.06493322551250458]

# %% [markdown]
# ## 6) Model Predict

# %%
look_ahead = 550

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model2.predict(np.array([xhat]), batch_size = 1, verbose = 0)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])

plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')
plt.legend()
plt.show()

# %% [markdown]
# # 6. Gated Recurrent Unit

# %% [markdown]
# > ## 1) Model Define

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU

model3 = Sequential(name = 'GRU')
model3.add(GRU(64, input_shape = (None, 1)))
model3.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# * Model Summary

# %%
model3.summary()
# Out:
# Model: "GRU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                12864
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12929 (50.50 KB)
# Trainable params: 12929 (50.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
model3.compile(loss = 'mse',
              optimizer = 'adam',
              metrics = ['mae'])

# %% [markdown]
# > ## 3) Model Fit
#
# * 약 10분

# %%
# %%time

hist3 = model3.fit(train_X, train_y,
                 epochs = 100,
                 batch_size = 16,
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/100
# 149/149 [==============================] - 4s 13ms/step - loss: 0.0240 - mae: 0.1132 - val_loss: 0.0134 - val_mae: 0.0904
# Epoch 2/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0130 - mae: 0.0874 - val_loss: 0.0113 - val_mae: 0.0832
# Epoch 3/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0113 - mae: 0.0810 - val_loss: 0.0108 - val_mae: 0.0775
# Epoch 4/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0104 - mae: 0.0775 - val_loss: 0.0092 - val_mae: 0.0729
# Epoch 5/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0096 - mae: 0.0746 - val_loss: 0.0091 - val_mae: 0.0745
# Epoch 6/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0093 - mae: 0.0732 - val_loss: 0.0084 - val_mae: 0.0697
# Epoch 7/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0091 - mae: 0.0719 - val_loss: 0.0087 - val_mae: 0.0699
# Epoch 8/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0089 - mae: 0.0707 - val_loss: 0.0087 - val_mae: 0.0703
# Epoch 9/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0088 - mae: 0.0702 - val_loss: 0.0083 - val_mae: 0.0706
# Epoch 10/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0088 - mae: 0.0704 - val_loss: 0.0086 - val_mae: 0.0692
# Epoch 11/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0087 - mae: 0.0698 - val_loss: 0.0082 - val_mae: 0.0678
# Epoch 12/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0088 - mae: 0.0702 - val_loss: 0.0080 - val_mae: 0.0677
# Epoch 13/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0700 - val_loss: 0.0093 - val_mae: 0.0765
# Epoch 14/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0087 - mae: 0.0699 - val_loss: 0.0081 - val_mae: 0.0684
# Epoch 15/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0087 - mae: 0.0702 - val_loss: 0.0081 - val_mae: 0.0684
# Epoch 16/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0087 - mae: 0.0699 - val_loss: 0.0082 - val_mae: 0.0694
# Epoch 17/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0088 - mae: 0.0702 - val_loss: 0.0085 - val_mae: 0.0706
# Epoch 18/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0702 - val_loss: 0.0084 - val_mae: 0.0710
# Epoch 19/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0698 - val_loss: 0.0081 - val_mae: 0.0687
# Epoch 20/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0698 - val_loss: 0.0080 - val_mae: 0.0676
# Epoch 21/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0082 - val_mae: 0.0677
# Epoch 22/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0083 - val_mae: 0.0698
# Epoch 23/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0087 - mae: 0.0699 - val_loss: 0.0088 - val_mae: 0.0735
# Epoch 24/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0698 - val_loss: 0.0080 - val_mae: 0.0678
# Epoch 25/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0082 - val_mae: 0.0694
# Epoch 26/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0700 - val_loss: 0.0081 - val_mae: 0.0685
# Epoch 27/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0081 - val_mae: 0.0687
# Epoch 28/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0087 - mae: 0.0697 - val_loss: 0.0082 - val_mae: 0.0698
# Epoch 29/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0080 - val_mae: 0.0685
# Epoch 30/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0084 - val_mae: 0.0684
# Epoch 31/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0087 - mae: 0.0695 - val_loss: 0.0080 - val_mae: 0.0678
# Epoch 32/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0082 - val_mae: 0.0692
# Epoch 33/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0080 - val_mae: 0.0677
# Epoch 34/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0697 - val_loss: 0.0081 - val_mae: 0.0684
# Epoch 35/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0081 - val_mae: 0.0694
# Epoch 36/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0081 - val_mae: 0.0685
# Epoch 37/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0081 - val_mae: 0.0685
# Epoch 38/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0086 - mae: 0.0696 - val_loss: 0.0081 - val_mae: 0.0680
# Epoch 39/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0086 - mae: 0.0697 - val_loss: 0.0083 - val_mae: 0.0678
# Epoch 40/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0086 - mae: 0.0697 - val_loss: 0.0081 - val_mae: 0.0680
# Epoch 41/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0083 - val_mae: 0.0701
# Epoch 42/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0695 - val_loss: 0.0081 - val_mae: 0.0684
# Epoch 43/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0695 - val_loss: 0.0083 - val_mae: 0.0679
# Epoch 44/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0080 - val_mae: 0.0674
# Epoch 45/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0690 - val_loss: 0.0080 - val_mae: 0.0672
# Epoch 46/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0081 - val_mae: 0.0672
# Epoch 47/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0086 - mae: 0.0688 - val_loss: 0.0080 - val_mae: 0.0680
# Epoch 48/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0692 - val_loss: 0.0079 - val_mae: 0.0677
# Epoch 49/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0079 - val_mae: 0.0675
# Epoch 50/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0082 - val_mae: 0.0700
# Epoch 51/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0695 - val_loss: 0.0082 - val_mae: 0.0674
# Epoch 52/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0695 - val_loss: 0.0080 - val_mae: 0.0684
# Epoch 53/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0087 - val_mae: 0.0727
# Epoch 54/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0694 - val_loss: 0.0079 - val_mae: 0.0673
# Epoch 55/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0080 - val_mae: 0.0673
# Epoch 56/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0080 - val_mae: 0.0672
# Epoch 57/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0086 - mae: 0.0692 - val_loss: 0.0082 - val_mae: 0.0698
# Epoch 58/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0085 - mae: 0.0689 - val_loss: 0.0079 - val_mae: 0.0672
# Epoch 59/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0084 - val_mae: 0.0708
# Epoch 60/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0692 - val_loss: 0.0084 - val_mae: 0.0704
# Epoch 61/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - mae: 0.0695 - val_loss: 0.0079 - val_mae: 0.0676
# Epoch 62/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0086 - mae: 0.0690 - val_loss: 0.0079 - val_mae: 0.0670
# Epoch 63/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0085 - mae: 0.0692 - val_loss: 0.0083 - val_mae: 0.0698
# Epoch 64/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0689 - val_loss: 0.0090 - val_mae: 0.0721
# Epoch 65/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0689 - val_loss: 0.0081 - val_mae: 0.0681
# Epoch 66/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0690 - val_loss: 0.0079 - val_mae: 0.0675
# Epoch 67/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0079 - val_mae: 0.0680
# Epoch 68/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0690 - val_loss: 0.0078 - val_mae: 0.0672
# Epoch 69/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0689 - val_loss: 0.0079 - val_mae: 0.0675
# Epoch 70/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0085 - mae: 0.0690 - val_loss: 0.0079 - val_mae: 0.0672
# Epoch 71/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0086 - mae: 0.0690 - val_loss: 0.0079 - val_mae: 0.0679
# Epoch 72/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0080 - val_mae: 0.0683
# Epoch 73/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0690 - val_loss: 0.0082 - val_mae: 0.0702
# Epoch 74/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0078 - val_mae: 0.0678
# Epoch 75/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0688 - val_loss: 0.0081 - val_mae: 0.0689
# Epoch 76/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - mae: 0.0689 - val_loss: 0.0079 - val_mae: 0.0681
# Epoch 77/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0085 - mae: 0.0691 - val_loss: 0.0078 - val_mae: 0.0671
# Epoch 78/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0085 - mae: 0.0689 - val_loss: 0.0079 - val_mae: 0.0680
# Epoch 79/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0084 - mae: 0.0684 - val_loss: 0.0081 - val_mae: 0.0674
# Epoch 80/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0079 - val_mae: 0.0666
# Epoch 81/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0686 - val_loss: 0.0078 - val_mae: 0.0665
# Epoch 82/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0688 - val_loss: 0.0078 - val_mae: 0.0664
# Epoch 83/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0079 - val_mae: 0.0664
# Epoch 84/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0078 - val_mae: 0.0666
# Epoch 85/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0085 - mae: 0.0686 - val_loss: 0.0079 - val_mae: 0.0679
# Epoch 86/100
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0085 - mae: 0.0688 - val_loss: 0.0077 - val_mae: 0.0668
# Epoch 87/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0084 - mae: 0.0690 - val_loss: 0.0079 - val_mae: 0.0663
# Epoch 88/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0080 - val_mae: 0.0691
# Epoch 89/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0081 - val_mae: 0.0667
# Epoch 90/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0684 - val_loss: 0.0078 - val_mae: 0.0668
# Epoch 91/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0685 - val_loss: 0.0082 - val_mae: 0.0701
# Epoch 92/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0686 - val_loss: 0.0080 - val_mae: 0.0672
# Epoch 93/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0685 - val_loss: 0.0077 - val_mae: 0.0664
# Epoch 94/100
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0084 - mae: 0.0684 - val_loss: 0.0082 - val_mae: 0.0691
# Epoch 95/100
# 149/149 [==============================] - 2s 14ms/step - loss: 0.0084 - mae: 0.0684 - val_loss: 0.0081 - val_mae: 0.0690
# Epoch 96/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0078 - val_mae: 0.0664
# Epoch 97/100
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0084 - mae: 0.0683 - val_loss: 0.0079 - val_mae: 0.0685
# Epoch 98/100
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0083 - mae: 0.0684 - val_loss: 0.0078 - val_mae: 0.0671
# Epoch 99/100
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - mae: 0.0684 - val_loss: 0.0081 - val_mae: 0.0670
# Epoch 100/100
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0083 - mae: 0.0680 - val_loss: 0.0083 - val_mae: 0.0671
# CPU times: user 2min 44s, sys: 8.33 s, total: 2min 52s
# Wall time: 3min 24s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist3.history['loss'])
plt.plot(hist3.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model3.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model3.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.008819114416837692, 0.06797908991575241]
# Test Score:  [0.008259959518909454, 0.06712503731250763]

# %% [markdown]
# ## 6) Model Predict

# %%
look_ahead = 550

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model3.predict(np.array([xhat]), batch_size = 1, verbose = 0)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])

plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')
plt.legend()
plt.show()

# %% [markdown]
# # 7. Bidirectional LSTM Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional

model4 = Sequential(name = 'Bidirectional_LSTM')
model4.add(Bidirectional(LSTM(64,
                             input_shape = (None, 1))))
model4.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# * Model Summary

# %%
# model4.summary() error

# %% [markdown]
# > ## 2) Model Compile

# %%
model4.compile(loss = 'mse',
              optimizer = 'adam',
              metrics = ['mae'])

# %% [markdown]
# > ## 3) Model Fit
#
# * 약 10분

# %%
# %%time

hist4 = model4.fit(train_X, train_y,
                 epochs = 100,
                 batch_size = 16,
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/100
# 149/149 [==============================] - 8s 27ms/step - loss: 0.0205 - mae: 0.1072 - val_loss: 0.0147 - val_mae: 0.0956
# Epoch 2/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0146 - mae: 0.0922 - val_loss: 0.0153 - val_mae: 0.1009
# Epoch 3/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0130 - mae: 0.0875 - val_loss: 0.0111 - val_mae: 0.0802
# Epoch 4/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0119 - mae: 0.0834 - val_loss: 0.0114 - val_mae: 0.0844
# Epoch 5/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0110 - mae: 0.0801 - val_loss: 0.0104 - val_mae: 0.0782
# Epoch 6/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0102 - mae: 0.0771 - val_loss: 0.0098 - val_mae: 0.0763
# Epoch 7/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0097 - mae: 0.0753 - val_loss: 0.0088 - val_mae: 0.0718
# Epoch 8/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0092 - mae: 0.0733 - val_loss: 0.0095 - val_mae: 0.0764
# Epoch 9/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0090 - mae: 0.0722 - val_loss: 0.0083 - val_mae: 0.0691
# Epoch 10/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0087 - mae: 0.0709 - val_loss: 0.0093 - val_mae: 0.0765
# Epoch 11/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0086 - mae: 0.0705 - val_loss: 0.0081 - val_mae: 0.0692
# Epoch 12/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0084 - mae: 0.0695 - val_loss: 0.0080 - val_mae: 0.0690
# Epoch 13/100
# 149/149 [==============================] - 3s 23ms/step - loss: 0.0084 - mae: 0.0695 - val_loss: 0.0084 - val_mae: 0.0717
# Epoch 14/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0083 - mae: 0.0691 - val_loss: 0.0079 - val_mae: 0.0667
# Epoch 15/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0083 - mae: 0.0688 - val_loss: 0.0080 - val_mae: 0.0685
# Epoch 16/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0083 - mae: 0.0684 - val_loss: 0.0078 - val_mae: 0.0675
# Epoch 17/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0082 - mae: 0.0685 - val_loss: 0.0082 - val_mae: 0.0693
# Epoch 18/100
# 149/149 [==============================] - 4s 30ms/step - loss: 0.0082 - mae: 0.0682 - val_loss: 0.0080 - val_mae: 0.0682
# Epoch 19/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0082 - mae: 0.0683 - val_loss: 0.0076 - val_mae: 0.0657
# Epoch 20/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0082 - mae: 0.0681 - val_loss: 0.0081 - val_mae: 0.0691
# Epoch 21/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0082 - mae: 0.0683 - val_loss: 0.0076 - val_mae: 0.0653
# Epoch 22/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0082 - mae: 0.0681 - val_loss: 0.0080 - val_mae: 0.0684
# Epoch 23/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0079 - val_mae: 0.0677
# Epoch 24/100
# 149/149 [==============================] - 4s 24ms/step - loss: 0.0081 - mae: 0.0679 - val_loss: 0.0074 - val_mae: 0.0646
# Epoch 25/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0081 - mae: 0.0678 - val_loss: 0.0079 - val_mae: 0.0666
# Epoch 26/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0082 - val_mae: 0.0690
# Epoch 27/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0074 - val_mae: 0.0649
# Epoch 28/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0679 - val_loss: 0.0074 - val_mae: 0.0649
# Epoch 29/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0081 - mae: 0.0679 - val_loss: 0.0074 - val_mae: 0.0644
# Epoch 30/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0675 - val_loss: 0.0075 - val_mae: 0.0647
# Epoch 31/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0078 - val_mae: 0.0692
# Epoch 32/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0076 - val_mae: 0.0659
# Epoch 33/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0080 - mae: 0.0673 - val_loss: 0.0071 - val_mae: 0.0635
# Epoch 34/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0675 - val_loss: 0.0078 - val_mae: 0.0675
# Epoch 35/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0073 - val_mae: 0.0643
# Epoch 36/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0077 - val_mae: 0.0662
# Epoch 37/100
# 149/149 [==============================] - 3s 23ms/step - loss: 0.0080 - mae: 0.0670 - val_loss: 0.0072 - val_mae: 0.0645
# Epoch 38/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0080 - mae: 0.0669 - val_loss: 0.0075 - val_mae: 0.0658
# Epoch 39/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0661
# Epoch 40/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0673 - val_loss: 0.0078 - val_mae: 0.0677
# Epoch 41/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0074 - val_mae: 0.0653
# Epoch 42/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0085 - val_mae: 0.0733
# Epoch 43/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0077 - val_mae: 0.0687
# Epoch 44/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0070 - val_mae: 0.0631
# Epoch 45/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0077 - val_mae: 0.0673
# Epoch 46/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0073 - val_mae: 0.0643
# Epoch 47/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0079 - mae: 0.0668 - val_loss: 0.0072 - val_mae: 0.0643
# Epoch 48/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0079 - mae: 0.0670 - val_loss: 0.0074 - val_mae: 0.0653
# Epoch 49/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0079 - mae: 0.0663 - val_loss: 0.0076 - val_mae: 0.0678
# Epoch 50/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0080 - val_mae: 0.0676
# Epoch 51/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0076 - val_mae: 0.0677
# Epoch 52/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0072 - val_mae: 0.0643
# Epoch 53/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0073 - val_mae: 0.0649
# Epoch 54/100
# 149/149 [==============================] - 4s 24ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0075 - val_mae: 0.0658
# Epoch 55/100
# 149/149 [==============================] - 5s 30ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0076 - val_mae: 0.0669
# Epoch 56/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0079 - mae: 0.0662 - val_loss: 0.0075 - val_mae: 0.0666
# Epoch 57/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0070 - val_mae: 0.0629
# Epoch 58/100
# 149/149 [==============================] - 5s 33ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0075 - val_mae: 0.0663
# Epoch 59/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0074 - val_mae: 0.0641
# Epoch 60/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0071 - val_mae: 0.0635
# Epoch 61/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0073 - val_mae: 0.0643
# Epoch 62/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0071 - val_mae: 0.0636
# Epoch 63/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0071 - val_mae: 0.0633
# Epoch 64/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0665 - val_loss: 0.0071 - val_mae: 0.0633
# Epoch 65/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0073 - val_mae: 0.0644
# Epoch 66/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0075 - val_mae: 0.0662
# Epoch 67/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0072 - val_mae: 0.0633
# Epoch 68/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0071 - val_mae: 0.0635
# Epoch 69/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0078 - mae: 0.0658 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 70/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0078 - mae: 0.0666 - val_loss: 0.0071 - val_mae: 0.0633
# Epoch 71/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0072 - val_mae: 0.0637
# Epoch 72/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0665 - val_loss: 0.0080 - val_mae: 0.0687
# Epoch 73/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0664 - val_loss: 0.0073 - val_mae: 0.0645
# Epoch 74/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0077 - val_mae: 0.0686
# Epoch 75/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0071 - val_mae: 0.0636
# Epoch 76/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0073 - val_mae: 0.0661
# Epoch 77/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0665 - val_loss: 0.0073 - val_mae: 0.0638
# Epoch 78/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0078 - val_mae: 0.0693
# Epoch 79/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0076 - val_mae: 0.0667
# Epoch 80/100
# 149/149 [==============================] - 3s 23ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0074 - val_mae: 0.0659
# Epoch 81/100
# 149/149 [==============================] - 4s 24ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0071 - val_mae: 0.0638
# Epoch 82/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0075 - val_mae: 0.0664
# Epoch 83/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0075 - val_mae: 0.0666
# Epoch 84/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0078 - mae: 0.0665 - val_loss: 0.0073 - val_mae: 0.0646
# Epoch 85/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0076 - val_mae: 0.0672
# Epoch 86/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0074 - val_mae: 0.0658
# Epoch 87/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0077 - mae: 0.0658 - val_loss: 0.0075 - val_mae: 0.0672
# Epoch 88/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0078 - mae: 0.0664 - val_loss: 0.0073 - val_mae: 0.0643
# Epoch 89/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0077 - mae: 0.0658 - val_loss: 0.0069 - val_mae: 0.0630
# Epoch 90/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0073 - val_mae: 0.0655
# Epoch 91/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0078 - val_mae: 0.0681
# Epoch 92/100
# 149/149 [==============================] - 2s 15ms/step - loss: 0.0077 - mae: 0.0661 - val_loss: 0.0073 - val_mae: 0.0655
# Epoch 93/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0073 - val_mae: 0.0641
# Epoch 94/100
# 149/149 [==============================] - 4s 26ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0072 - val_mae: 0.0637
# Epoch 95/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0077 - mae: 0.0658 - val_loss: 0.0070 - val_mae: 0.0628
# Epoch 96/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0665 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 97/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0072 - val_mae: 0.0633
# Epoch 98/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0071 - val_mae: 0.0640
# Epoch 99/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0072 - val_mae: 0.0642
# Epoch 100/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0073 - val_mae: 0.0648
# CPU times: user 4min 37s, sys: 12.6 s, total: 4min 50s
# Wall time: 5min 25s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist4.history['loss'])
plt.plot(hist4.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model4.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model4.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.007765231188386679, 0.06690365076065063]
# Test Score:  [0.0073060765862464905, 0.06476271152496338]

# %% [markdown]
# ## 6) Model Predict

# %%
look_ahead = 550

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model4.predict(np.array([xhat]), batch_size = 1, verbose = 0)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])

plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')
plt.legend()
plt.show()

# %% [markdown]
# # The End
